# %% [markdown]
# # Week 13:  Object-oriented programming HW

# %% [markdown]
# ## Exercise 1  (from Monday's class)

# %% [markdown]
# 1. Write a ``Particle`` class that can be used to represent a particle with a mass, a 3-d position, and a 3-d velocity.
#
# 2. Write a method that can be used to compute the kinetic energy of the particle
#
# 3. Write a method that takes another particle as an argument and finds the distance between the two particles
#
# 4. Write a method that given a time interval ``dt`` will update the position of the particle to the new position based on the current position and velocity.
#
# 5. Write a ``ChargedParticle`` class that inherits from the ``Particle`` class, but also has an attribute for the charge of the particle.

# %%
import numpy as np
# your solution here

class Particle(object):
    def __init__(self,m,x,y,z,vx,vy,vz):
        self.m = m
        self.x = x
        self.y = y
        self.z = z
        self.vx = vx
        self.vy = vy
        self.vz = vz
    
    def kinetic_energy(self):
        return .5*self.m*(self.vx**2 + self.vy**2 + self.vz**2)
    
    def distance(self,other):
        return np.sqrt((self.x-other.x)**2 + (self.y-other.y)**2 + (self.z-other.z)**2)
    
    def new_position(self,dt):
        self.x = self.x + dt*self.vx
        self.y = self.y + dt*self.vy
        self.z = self.z + dt*self.vz
        return [self.x,self.y,self.z]

class ChargedParticle(Particle):

    def __init__(self,mass, x, y, z, vx, vy, vz, charge):
        self.m = mass
        self.x = x
        self.y = y
        self.z = z
        self.vx = vx
        self.vy = vy
        self.vz = vz
        self.charge = charge
        
    def interact(self,other):
        if self.distance(other) < .25:
            if (self.charge < 0 and other.charge > 0) | (self.charge > 0 and other.charge < 0): 
                self.vx = 0
                self.vy = 0
                self.vz = 0
                self.charge = 0
                other.vx = 0
                other.vy = 0
                other.vz = 0
                other.charge = 0
                print('Merge')
            else:
                self.vx = -1*(self.charge+other.charge)*(self.m/other.m)
                self.vy = -1*(self.charge+other.charge)*(self.m/other.m)
                self.vz = -1*(self.charge+other.charge)*(self.m/other.m)
                other.vx = -1*(self.charge+other.charge)*(other.m/self.m)
                other.vy = -1*(self.charge+other.charge)*(other.m/self.m)
                other.vz = -1*(self.charge+other.charge)*(other.m/self.m)
                print('Repel')

# %% [markdown]
# ## Exercise 2  (New)

# %% [markdown]
# 6. Write a method that can be used to see if a particle is in the same place (e.g., find_seperation < 0.25).  If there are two ChargedParticles in the same place make a "simple" (not correct physics) "interaction". (__have the code print "interaction"__).
#
#     a. If the charges are opposite, make them "combine", set both velocities to zero and set their charge to zero, and print "merge".
#
#     b. Else, make the particles "repel", to do:
#
#         multiply each "self" velocity and  by (-1 * (self.charge+other.charge) * (self.mass/other.mass))
#
#         multiply each "other" velocity by (-1 * (self.charge+other.charge) * (other.mass/self.mass))
#
#     e.g., reversing it's velocity, and print "repel". __(Again this is bad physics, but we are focusing on coding so play along.)__
#
#
# 7. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (1,1,1) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-1,-1,-1) and (charge = -0.5).
#
#     Use your dt time interval to move the particles in 0.5 time steps for 50 steps, and print the current poition and velocity of each particle at each time step.
#
#
# 8. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (2,2,2) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-2,-2,-2) and (charge = 2.0).
#
#     Use your dt time interval to move the particles in 0.5 time steps for 50 steps, and print the current poition and velocity of each particle at each time step.

# %%
p1 = ChargedParticle(5,-5,-5,-5,1,1,1,.5)
p2 = ChargedParticle(10,5,5,5,-1,-1,-1,-.5)

for i in range(50):
    dt = .5
    if p1.vx == 0:
        break
    else:
        vel1 = [p1.vx,p1.vy,p1.vz]
        vel2 = [p2.vx,p2.vy,p2.vz]
        pos1 = [p1.x,p1.y,p1.z]
        pos2 = [p2.x,p2.y,p2.z]
        print('P1 position '+str(pos1))
        print('P1 velocity '+ str(vel1))
        print('P2 position '+str(pos2))
        print('P2 velocity '+ str(vel2))
        p1.interact(p2)
        p1.new_position(dt)
        p2.new_position(dt)
# Out:
# P1 position [-5, -5, -5]
# P1 velocity [1, 1, 1]
# P2 position [5, 5, 5]
# P2 velocity [-1, -1, -1]
# P1 position [-4.5, -4.5, -4.5]
# P1 velocity [1, 1, 1]
# P2 position [4.5, 4.5, 4.5]
# P2 velocity [-1, -1, -1]
# P1 position [-4.0, -4.0, -4.0]
# P1 velocity [1, 1, 1]
# P2 position [4.0, 4.0, 4.0]
# P2 velocity [-1, -1, -1]
# P1 position [-3.5, -3.5, -3.5]
# P1 velocity [1, 1, 1]
# P2 position [3.5, 3.5, 3.5]
# P2 velocity [-1, -1, -1]
# P1 position [-3.0, -3.0, -3.0]
# P1 velocity [1, 1, 1]
# P2 position [3.0, 3.0, 3.0]
# P2 velocity [-1, -1, -1]
# P1 position [-2.5, -2.5, -2.5]
# P1 velocity [1, 1, 1]
# P2 position [2.5, 2.5, 2.5]
# P2 velocity [-1, -1, -1]
# P1 position [-2.0, -2.0, -2.0]
# P1 velocity [1, 1, 1]
# P2 position [2.0, 2.0, 2.0]
# P2 velocity [-1, -1, -1]
# P1 position [-1.5, -1.5, -1.5]
# P1 velocity [1, 1, 1]
# P2 position [1.5, 1.5, 1.5]
# P2 velocity [-1, -1, -1]
# P1 position [-1.0, -1.0, -1.0]
# P1 velocity [1, 1, 1]
# P2 position [1.0, 1.0, 1.0]
# P2 velocity [-1, -1, -1]
# P1 position [-0.5, -0.5, -0.5]
# P1 velocity [1, 1, 1]
# P2 position [0.5, 0.5, 0.5]
# P2 velocity [-1, -1, -1]
# P1 position [0.0, 0.0, 0.0]
# P1 velocity [1, 1, 1]
# P2 position [0.0, 0.0, 0.0]
# P2 velocity [-1, -1, -1]
# Merge

# %%
p1 = ChargedParticle(5,-5,-5,-5,2,2,2,.5)
p2 = ChargedParticle(10,5,5,5,-2,-2,-2,2)

for i in range(50):
    dt = .5
    if p1.vx == 0:
        break
    else:
        vel1 = [p1.vx,p1.vy,p1.vz]
        vel2 = [p2.vx,p2.vy,p2.vz]
        pos1 = [p1.x,p1.y,p1.z]
        pos2 = [p2.x,p2.y,p2.z]
        print('P1 position '+str(pos1))
        print('P1 velocity '+ str(vel1))
        print('P2 position '+str(pos2))
        print('P1 velocity '+ str(vel2))
        p1.interact(p2)
        p1.new_position(dt)
        p2.new_position(dt)
# Out:
# P1 position [-5, -5, -5]
# P1 velocity [2, 2, 2]
# P2 position [5, 5, 5]
# P1 velocity [-2, -2, -2]
# P1 position [-4.0, -4.0, -4.0]
# P1 velocity [2, 2, 2]
# P2 position [4.0, 4.0, 4.0]
# P1 velocity [-2, -2, -2]
# P1 position [-3.0, -3.0, -3.0]
# P1 velocity [2, 2, 2]
# P2 position [3.0, 3.0, 3.0]
# P1 velocity [-2, -2, -2]
# P1 position [-2.0, -2.0, -2.0]
# P1 velocity [2, 2, 2]
# P2 position [2.0, 2.0, 2.0]
# P1 velocity [-2, -2, -2]
# P1 position [-1.0, -1.0, -1.0]
# P1 velocity [2, 2, 2]
# P2 position [1.0, 1.0, 1.0]
# P1 velocity [-2, -2, -2]
# P1 position [0.0, 0.0, 0.0]
# P1 velocity [2, 2, 2]
# P2 position [0.0, 0.0, 0.0]
# P1 velocity [-2, -2, -2]
# Repel
# P1 position [-0.625, -0.625, -0.625]
# P1 velocity [-1.25, -1.25, -1.25]
# P2 position [-2.5, -2.5, -2.5]
# P1 velocity [-5.0, -5.0, -5.0]
# P1 position [-1.25, -1.25, -1.25]
# P1 velocity [-1.25, -1.25, -1.25]
# P2 position [-5.0, -5.0, -5.0]
# P1 velocity [-5.0, -5.0, -5.0]
# P1 position [-1.875, -1.875, -1.875]
# P1 velocity [-1.25, -1.25, -1.25]
# P2 position [